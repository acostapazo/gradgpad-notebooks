# %% [markdown]
# # The GRAD-GPAD framework 🗿

# %% [markdown]
# ### Installation

# %%
pip install -U gradgpad

# %% [markdown]
# ---
# ### Command Line Interface
#
# The `grad-gpad` framework has available a Command Line Interface.
# Please, check use help parameter to obtain updated information about available commands

# %%
# !gradgpad -h

# %% [markdown]
# ##### Reproducible Research
#
# To reproduce the research you only have to select an `<output>` folder an run the following command:

# %%
# !gradgpad --reproducible-research -o output

# %% [markdown]
# ##### Show Histograms
#
# Besides, `gradgpad` CLI can show the hist from score files
#
# For instance, if we want to visualize the hist of Quality-based approach, just type:

# %%
# !gradgpad --show-hist --score-filename-devel /srv/conda/envs/notebook/lib/python3.7/site_packages/gradgpad/reproducible_research/scores/quality_rbf/quality_rbf_grandtest_devel.json --score-filename-test /srv/conda/envs/notebook/lib/python3.7/site_packages/gradgpad/reproducible_research/scores/quality_rbf/quality_rbf_grandtest_test.json

# %% [markdown]
# Or for Auxiliary-based face-PAD approach

# %%
# !gradgpad --show-hist --score-filename-devel /srv/conda/envs/notebook/lib/python3.7/site_packages/gradgpad/reproducible_research/scores/auxiliary/auxiliary_grandtest_devel.json --score-filename-test /srv/conda/envs/notebook/lib/python3.7/site_packages/gradgpad/reproducible_research/scores/auxiliary/auxiliary_grandtest_test.json
